# %%
import numpy as np
import matplotlib.pyplot as plt


np.random.seed(42)

n_points = 600
time = np.arange(n_points)


X1 = np.random.binomial(1, 0.6, n_points)
X2 = np.zeros(n_points)
X3 = np.zeros(n_points)


for t in range(1, n_points):
    # X2 is more likely to happen if X1 happened in the previous step
    X2[t] = np.random.binomial(1, 0.5 * X1[t-1])
    # X3 is more likely to happen if X2 happened in the previous step
    X3[t] = np.random.binomial(1, 0.7 * X2[t-1] )



X1 = [time[i] for i in range(len(X1)) if X1[i] > 0]
X2 = [time[i] + 0.1 for i in range(len(X2)) if X2[i] > 0]
X3 = [time[i] + 0.2 for i in range(len(X3)) if X3[i] > 0]

# %%
def _plot_tick_bars(timestamps_i, ax, color):
    for t in timestamps_i:
        ax.axvline(x=t, color = color)
    # ax.set_title(label, fontsize=20)
    ax.get_yaxis().set_visible(False)
def _plot_tick_bars_causes(timestamps_i, ax, cause):
    colors = ['red', 'green', 'blue']
    for idx, t in enumerate(timestamps_i):
        cause_ = torch.argmax(cause[idx]).item()
        ax.axvline(x=t, color = colors[cause_])
    ax.get_yaxis().set_visible(False)

fig, ax = plt.subplots(nrows = 3, sharex = True)

_plot_tick_bars(X1, ax[0], color = 'red')
_plot_tick_bars(X2, ax[1], color = 'green')
_plot_tick_bars(X3, ax[2], color = 'blue')

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
# from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader

if torch.cuda.is_available():
    torch.set_default_tensor_type("torch.cuda.FloatTensor")
    device = "cuda"
else:
    torch.set_default_tensor_type("torch.FloatTensor")
    device = "cpu"

# %%
# s = torch.rand(size = (10,2, 1))
# F.interpolate(s, size= (4,1), mode='linear', align_corners=True).shape

# %%
class CausalConv1d(nn.Module):
    
    """
    A causal 1D convolution.
    """

    def __init__(self, in_channels, out_channels, kernel_size, dilation, A=True, **kwargs):
        super(CausalConv1d, self).__init__()

        # attributes:
        self.kernel_size = kernel_size
        self.dilation = dilation
        self.A = A # whether it to be causal (True), or not (False)
        
        self.padding = (kernel_size - 1) * dilation + A * 1

        # module:
        self.conv1d = torch.nn.Conv1d(in_channels, out_channels,
                                      kernel_size, stride=1,
                                      padding=0,
                                      dilation=dilation,
                                      **kwargs)

    def forward(self, x):
        x = torch.nn.functional.pad(x, (self.padding, 0))
        conv1d_out = self.conv1d(x)
        if self.A:
            return conv1d_out[:, :, : -1]
        else:
            return conv1d_out
    

class MemoryBasedCausalConv(nn.Module):

    def __init__(self, in_channels, hidden_dim, kernel_size, memory_dim):
        super().__init__()
        
        self.in_channels = in_channels
        self.hidden_dim = hidden_dim
        self.kernel_size = kernel_size
        self.memory_dim = memory_dim

        self.layers = nn.ModuleList()

        for i in range(1, self.memory_dim):
            block = nn.Sequential(
                CausalConv1d(in_channels = in_channels, out_channels = hidden_dim, kernel_size=self.kernel_size, dilation = i),
                # nn.LayerNorm(self.memory_dim),
                nn.LeakyReLU()
            )
            self.layers.append(block)
            in_channels = hidden_dim
        
        final_block = nn.Sequential(
                CausalConv1d(in_channels = in_channels, out_channels = 2*self.in_channels, kernel_size=self.kernel_size, dilation = self.memory_dim),
                # nn.Tanh()
        )
        
        self.layers.append(final_block)

    def forward(self, x):
        x = x.permute(0, 2, 1)
        for layer in self.layers:
            x = layer(x)
            

        x = x.permute(0, 2, 1)
        return x

# %%
from torch.distributions import Normal 


class AffineCouplingLayer(nn.Module):
    def __init__(self, num_features, hidden_dim, memory_dim = 4):
        super(AffineCouplingLayer, self).__init__()
        
        self.memory_dim = memory_dim
        self.net = MemoryBasedCausalConv(in_channels=num_features, hidden_dim=hidden_dim, kernel_size=2, memory_dim = memory_dim) #Conv1DModel(num_features, hidden_dim, num_filters=128)
        
    def forward(self, x):
        mask = torch.zeros(size = (1, self.memory_dim, 1))
        mask[:, :self.memory_dim//2, :] = 1
        x1 = x*mask
        # x2 = x*(1-mask)
        params = self.net(x1)
        shift, log_scale = params.chunk(2, dim=-1)
        shift = shift*(1-mask)
        log_scale = log_scale*(1-mask)
        # z2 = (x2 - shift) * torch.exp(-log_scale)
        z = (x + shift)*torch.exp(log_scale) #x1 + z2    #torch.cat([x1, z2], dim=1)
        log_det_jacobian = log_scale.sum(dim=(1,))
        
        return z, log_det_jacobian

    def inverse(self, z):
        z1, z2 = z.chunk(2, dim=1)
        params = self.net(z1)
        shift, log_scale = params.chunk(2, dim=-1)
        x2 = z2 * torch.exp(log_scale) + shift
        x = torch.cat([z1, x2], dim=-1)
        
        return x



class InvConv1D(nn.Module):
    def __init__(self, num_features):
        super().__init__()
        # Initialize an orthogonal matrix for 1x1 convolution in 1D
        w_init, _ = torch.linalg.qr(torch.randn(num_features, num_features))
        #w_init = torch.tensor(w_init)

        self.register_buffer('w', w_init)
        self.w_inverse = None

    def forward(self, x):
        # x is of shape (batch_size, num_features)
        # Apply the learned 1x1 convolution (linear transformation)
        z = self.w @ x   # Matrix multiplication for 1D

        # Compute log determinant of the Jacobian for the flow
        log_det_jacobian = torch.slogdet(self.w)[1] * x.size(1)
        
        return z, log_det_jacobian

    def inverse(self, z):
        if self.w_inverse is None:
            self.w_inverse = torch.inverse(self.w)
        x = self.w_inverse @ z
        
        return x



class NFBlock(nn.Module):
    def __init__(self, num_features, hidden_dim, memory_dim):
        super().__init__()
        self.invertible_conv = InvConv1D(memory_dim)
        self.affine_coupling = AffineCouplingLayer(num_features = num_features, hidden_dim = hidden_dim, memory_dim = memory_dim)

    def forward(self, x):
        z, log_det_jacobian_conv = self.invertible_conv(x)
        
        z, log_det_jacobian_affine = self.affine_coupling(z)
        
        # print(log_det_jacobian_conv, log_det_jacobian_affine)
        
        log_det_jacobian = log_det_jacobian_conv + log_det_jacobian_affine
        
        return z,log_det_jacobian

    def inverse(self, z):
        x = self.affine_coupling.inverse(z)
        x = self.invertible_conv.inverse(x)
        
        return x



class NormalizingFlow(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, memory_dim):
        super(NormalizingFlow, self).__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.base_dist = Normal(0, 1)
        self.blocks = nn.ModuleList(
            [NFBlock(num_features = input_dim, hidden_dim = hidden_dim, memory_dim = memory_dim) for _ in range(num_layers)]
        )
        
    
    def forward(self, x):
        log_det_jacobian = 0
        
        for layer in self.blocks:
            x, ldj = layer(x)
            log_det_jacobian += ldj
        
        return x, log_det_jacobian

    def inverse(self, z):
        for layer in reversed(self.blocks):
            z = layer.inverse(z)
        return z


    def log_prob(self, x):
        z, ldj = self.forward(x)
        log_pz = self.base_dist.log_prob(z).sum(dim = (1,))
        log_px = log_pz + ldj

        return z, log_px

# %%
m = NormalizingFlow(input_dim=1, memory_dim = 4, hidden_dim = 64, num_layers = 4)
sum(p.numel() for p in m.parameters())
# Out:
# 67848

# %%
class GrangerMPP(nn.Module):

    def __init__(self, processes, memory_dim : int = 10):

        super().__init__()

        self.processes = processes
        self.memory_dim = memory_dim
        self.n_processes = len(self.processes)
        self.GrangerMatrix = nn.Parameter((torch.empty(self.n_processes, self.n_processes)))
        nn.init.eye_(self.GrangerMatrix)#, mean = 1, std = 0.1)


        self.models = nn.ModuleList([NormalizingFlow(input_dim=1, memory_dim = self.memory_dim, hidden_dim = 128, num_layers = 4) for i in range(self.n_processes)])
        self.sweep_dict = self.make_sweep_dict()
        self.time_of_start = self.get_time_of_start()
        self.optimizers = [torch.optim.Adam(list(self.models[i].parameters()), lr=1e-4, weight_decay = 1e-5) for i in range(self.n_processes)]
        self.g_optimizer = torch.optim.Adam([self.GrangerMatrix], lr = 1e-3, weight_decay=1e-5)
        self.log_GrangerMatrix = []


    def em_step(self, n_steps):
        dic = {}
        self.causes = [[], [], []]
        for i in range(self.n_processes):
            dic[i] = []


        taus = torch.linspace(1, 0.3, steps = n_steps)#
        
        for self.step in range(n_steps):
          for i_proc in range(self.n_processes):
              self.causes[i_proc] = []
              curr = processes[i_proc]
              len_curr = len(curr)
              idx_start = 0
              while idx_start < len_curr:
                self.num_events = 5
                events = self.get_events(self.num_events, idx_start, i_proc, 1.0) 
                if events:
                  DL = DataLoader(events, batch_size = len(events))
                  self.DL = DL

                  for X, cause_rank in DL:
                    X = X - X.min(1, keepdim=True)[0]/ (X.max(1, keepdim=True)[0] - X.min(1, keepdim=True)[0])
                    loss = self.m_step(i_proc, X, cause_rank)
                    dic[i_proc].append(loss)

                idx_start += self.num_events

              if (self.step + 1) % 5 == 0 or self.step == 0:
                  print(f'Step: {self.step + 1}, Model: {i_proc}, Loss: {loss}, Num of Events: {len(self.causes[i_proc])*self.num_events}')


        return dic

    def m_step(self, i_proc, X, cause_rank):

        model = self.models[i_proc]
        self.optimizers[i_proc].zero_grad()
        self.g_optimizer.zero_grad()
        X = X.unsqueeze(-1)
        
        z, logp = model.log_prob(X)
        loss = -1*logp

        loss_rnn = (loss * cause_rank).sum()/self.num_events  + -1*(torch.log(cause_rank + 1e-7)).sum()/self.num_events + 0.001*self.GrangerMatrix[i_proc].norm(p=1)


        if not (torch.isnan(loss_rnn) | torch.isinf(loss_rnn)):


            loss_rnn.backward(retain_graph = True)

            self.optimizers[i_proc].step()
            self.g_optimizer.step()
            self.log_GrangerMatrix.append(self.GrangerMatrix.clone().detach())


        else:
            print(f'NaN found in epoch: {self.step}')

        return loss_rnn.item()

    def make_sweep_dict(self):

        dic = {}
        for i in range(self.n_processes):
            target = self.processes[i]
            dic[i] = {}
            for j in range(self.n_processes):
                cause = self.processes[j]
                dic[i][j] = self.sweep(target, cause)

        return dic


    def sweep(self, pa, pc):
        events = []
        pa_indices = []


        for i, ia in enumerate(pa):
            events.append((ia, 'a'))
            pa_indices.append(i)

        for ic in pc:
            events.append((ic, 'c'))

        lim = self.memory_dim

        events.sort()
        mem = []
        ret = []
        index_start = False

        pa_idx_counter = 0  # Counter to track which index in pa we are at

        for t, e in events:
            if e == 'c':
                if len(mem) >= lim:
                    mem.pop(0)
                mem.append(t)

            if e == 'a':
                # Memory is not full yet
                if len(mem) < lim:
                    pa_idx_counter += 1  # Move to the next pa index
                    continue
                # Retrieve deltas from this time to the cause times
                pp = [t - tc for tc in mem]
                ret.append(pp)
                if not index_start:
                  index_start = pa_indices[pa_idx_counter] # Save index relative to pa
                pa_idx_counter += 1  # Move to the next pa index
        if not index_start:
          index_start = -1
        return torch.tensor(ret, dtype=torch.float), index_start

    def get_time_of_start(self):

      indexs = []
      dic = self.sweep_dict

      for i in dic:
        curr = []
        for j in dic[i]:
          curr.append(dic[i][j][1])
        indexs.append(curr)

      return indexs


    def new_e_step(self, num_events, i_proc, tau):

      in_ = self.GrangerMatrix[i_proc].abs()
      rv = []
      for i in range(num_events):
        cause = F.gumbel_softmax(
            in_,
            tau = tau,
            hard = False
        )
        rv.append(cause)

      self.causes[i_proc].append(rv)

      return rv


    def get_events(self, num_events, idx_start, i_proc, tau):

      begin_of_influences = self.time_of_start[i_proc]
      n_causes = self.new_e_step(num_events, i_proc, tau)

      event_cause = []

      for time in range(num_events):
        causes = n_causes[time]

        for idx_cause, cause in enumerate(causes):
          inf_begin = begin_of_influences[idx_cause]

          if inf_begin == -1: 
            continue

          else:
            if time + idx_start >= inf_begin and len(self.sweep_dict[i_proc][idx_cause][0]) > time + idx_start + inf_begin:
            
              where = time + idx_start - inf_begin
              app = (self.sweep_dict[i_proc][idx_cause][0][where], cause)
              event_cause.append(app)

      return event_cause

# %%
X1_ = torch.tensor(X1.copy(), dtype = torch.float32)
X2_ = torch.tensor(X2.copy(), dtype = torch.float32)
X3_ = torch.tensor(X3.copy(), dtype = torch.float32)
processes = [X1_, X2_, X3_]

# %%
mpp = GrangerMPP(processes, memory_dim = 10)
l = mpp.em_step(n_steps = 200)
# Out:
# Step: 1, Model: 0, Loss: 498.71673583984375, Num of Events: 350
# Step: 1, Model: 1, Loss: 149.79371643066406, Num of Events: 170
# Step: 1, Model: 2, Loss: 11.023765563964844, Num of Events: 115
# Step: 5, Model: 0, Loss: 52.923194885253906, Num of Events: 350
# Step: 5, Model: 1, Loss: 16.039060592651367, Num of Events: 170
# Step: 5, Model: 2, Loss: 6.589322566986084, Num of Events: 115
# Step: 10, Model: 0, Loss: 25.599708557128906, Num of Events: 350
# Step: 10, Model: 1, Loss: 33.18405532836914, Num of Events: 170
# Step: 10, Model: 2, Loss: 1.5653438568115234, Num of Events: 115
# Step: 15, Model: 0, Loss: 55.83158874511719, Num of Events: 350
# Step: 15, Model: 1, Loss: 16.80986785888672, Num of Events: 170
# Step: 15, Model: 2, Loss: 5.166508197784424, Num of Events: 115
# Step: 20, Model: 0, Loss: 49.35698318481445, Num of Events: 350
# Step: 20, Model: 1, Loss: 24.834630966186523, Num of Events: 170
# Step: 20, Model: 2, Loss: 1.6671327352523804, Num of Events: 115
# Step: 25, Model: 0, Loss: 28.27739906311035, Num of Events: 350
# Step: 25, Model: 1, Loss: 12.402877807617188, Num of Events: 170
# Step: 25, Model: 2, Loss: 1.1342805624008179, Num of Events: 115
# Step: 30, Model: 0, Loss: 43.94597244262695, Num of Events: 350
# Step: 30, Model: 1, Loss: 9.729837417602539, Num of Events: 170
# Step: 30, Model: 2, Loss: 4.344695568084717, Num of Events: 115
# Step: 35, Model: 0, Loss: 30.464262008666992, Num of Events: 350
# Step: 35, Model: 1, Loss: 15.773240089416504, Num of Events: 170
# Step: 35, Model: 2, Loss: 2.7697386741638184, Num of Events: 115
# Step: 40, Model: 0, Loss: 34.93361282348633, Num of Events: 350
# Step: 40, Model: 1, Loss: 20.053482055664062, Num of Events: 170
# Step: 40, Model: 2, Loss: 6.102729320526123, Num of Events: 115
# Step: 45, Model: 0, Loss: 65.16500854492188, Num of Events: 350
# Step: 45, Model: 1, Loss: 14.697700500488281, Num of Events: 170
# Step: 45, Model: 2, Loss: 1.271283507347107, Num of Events: 115
# Step: 50, Model: 0, Loss: 35.04252243041992, Num of Events: 350
# Step: 50, Model: 1, Loss: 24.91388702392578, Num of Events: 170
# Step: 50, Model: 2, Loss: 1.2984592914581299, Num of Events: 115
# Step: 55, Model: 0, Loss: 12.44306755065918, Num of Events: 350
# Step: 55, Model: 1, Loss: 6.781476974487305, Num of Events: 170
# Step: 55, Model: 2, Loss: 2.2686328887939453, Num of Events: 115
# Step: 60, Model: 0, Loss: 31.15751075744629, Num of Events: 350
# Step: 60, Model: 1, Loss: 40.804744720458984, Num of Events: 170
# Step: 60, Model: 2, Loss: 2.6591391563415527, Num of Events: 115
# Step: 65, Model: 0, Loss: 54.118408203125, Num of Events: 350
# Step: 65, Model: 1, Loss: 27.914878845214844, Num of Events: 170
# Step: 65, Model: 2, Loss: 1.7197962999343872, Num of Events: 115
# Step: 70, Model: 0, Loss: 53.764854431152344, Num of Events: 350
# Step: 70, Model: 1, Loss: 9.75125789642334, Num of Events: 170
# Step: 70, Model: 2, Loss: 1.541738510131836, Num of Events: 115
# Step: 75, Model: 0, Loss: 41.66246795654297, Num of Events: 350
# Step: 75, Model: 1, Loss: 6.667915344238281, Num of Events: 170
# Step: 75, Model: 2, Loss: 0.9590620994567871, Num of Events: 115
# Step: 80, Model: 0, Loss: 24.080509185791016, Num of Events: 350
# Step: 80, Model: 1, Loss: 13.563459396362305, Num of Events: 170
# Step: 80, Model: 2, Loss: 1.4477075338363647, Num of Events: 115
# Step: 85, Model: 0, Loss: 27.77932357788086, Num of Events: 350
# Step: 85, Model: 1, Loss: 17.283851623535156, Num of Events: 170
# Step: 85, Model: 2, Loss: 1.235236406326294, Num of Events: 115
# Step: 90, Model: 0, Loss: 43.840126037597656, Num of Events: 350
# Step: 90, Model: 1, Loss: 21.700178146362305, Num of Events: 170
# Step: 90, Model: 2, Loss: 2.1795480251312256, Num of Events: 115
# Step: 95, Model: 0, Loss: 30.68773651123047, Num of Events: 350
# Step: 95, Model: 1, Loss: 21.323528289794922, Num of Events: 170
# Step: 95, Model: 2, Loss: 2.170335531234741, Num of Events: 115
# Step: 100, Model: 0, Loss: 39.57416534423828, Num of Events: 350
# Step: 100, Model: 1, Loss: 15.353411674499512, Num of Events: 170
# Step: 100, Model: 2, Loss: 0.9135482311248779, Num of Events: 115
# Step: 105, Model: 0, Loss: 44.44378662109375, Num of Events: 350
# Step: 105, Model: 1, Loss: 14.428287506103516, Num of Events: 170
# Step: 105, Model: 2, Loss: 0.9580771923065186, Num of Events: 115
# Step: 110, Model: 0, Loss: 57.288047790527344, Num of Events: 350
# Step: 110, Model: 1, Loss: 26.505294799804688, Num of Events: 170
# Step: 110, Model: 2, Loss: 0.9678629636764526, Num of Events: 115
# Step: 115, Model: 0, Loss: 18.374622344970703, Num of Events: 350
# Step: 115, Model: 1, Loss: 28.937501907348633, Num of Events: 170
# Step: 115, Model: 2, Loss: 0.9767552614212036, Num of Events: 115
# Step: 120, Model: 0, Loss: 33.657936096191406, Num of Events: 350
# Step: 120, Model: 1, Loss: 7.558145523071289, Num of Events: 170
# Step: 120, Model: 2, Loss: 0.9785491228103638, Num of Events: 115
# Step: 125, Model: 0, Loss: 47.521881103515625, Num of Events: 350
# Step: 125, Model: 1, Loss: 7.307030200958252, Num of Events: 170
# Step: 125, Model: 2, Loss: 1.3424919843673706, Num of Events: 115
# Step: 130, Model: 0, Loss: 42.53654479980469, Num of Events: 350
# Step: 130, Model: 1, Loss: 33.68788528442383, Num of Events: 170
# Step: 130, Model: 2, Loss: 0.9872366786003113, Num of Events: 115
# Step: 135, Model: 0, Loss: 32.27735900878906, Num of Events: 350
# Step: 135, Model: 1, Loss: 17.079565048217773, Num of Events: 170
# Step: 135, Model: 2, Loss: 0.9110041856765747, Num of Events: 115
# Step: 140, Model: 0, Loss: 31.315507888793945, Num of Events: 350
# Step: 140, Model: 1, Loss: 17.34568214416504, Num of Events: 170
# Step: 140, Model: 2, Loss: 0.9555825591087341, Num of Events: 115
# Step: 145, Model: 0, Loss: 37.29484939575195, Num of Events: 350
# Step: 145, Model: 1, Loss: 17.598108291625977, Num of Events: 170
# Step: 145, Model: 2, Loss: 1.1110481023788452, Num of Events: 115
# Step: 150, Model: 0, Loss: 24.573909759521484, Num of Events: 350
# Step: 150, Model: 1, Loss: 11.133705139160156, Num of Events: 170
# Step: 150, Model: 2, Loss: 1.8084527254104614, Num of Events: 115
# Step: 155, Model: 0, Loss: 27.23325538635254, Num of Events: 350
# Step: 155, Model: 1, Loss: 4.427633762359619, Num of Events: 170
# Step: 155, Model: 2, Loss: 1.0307703018188477, Num of Events: 115
# Step: 160, Model: 0, Loss: 38.35539245605469, Num of Events: 350
# Step: 160, Model: 1, Loss: 4.135725498199463, Num of Events: 170
# Step: 160, Model: 2, Loss: 2.9104819297790527, Num of Events: 115
# Step: 165, Model: 0, Loss: 55.86973571777344, Num of Events: 350
# Step: 165, Model: 1, Loss: 19.406953811645508, Num of Events: 170
# Step: 165, Model: 2, Loss: 1.0413610935211182, Num of Events: 115
# Step: 170, Model: 0, Loss: 38.90375900268555, Num of Events: 350
# Step: 170, Model: 1, Loss: 13.073206901550293, Num of Events: 170
# Step: 170, Model: 2, Loss: 0.9195508360862732, Num of Events: 115
# Step: 175, Model: 0, Loss: 35.11511993408203, Num of Events: 350
# Step: 175, Model: 1, Loss: 8.007402420043945, Num of Events: 170
# Step: 175, Model: 2, Loss: 6.024163246154785, Num of Events: 115
# Step: 180, Model: 0, Loss: 30.556184768676758, Num of Events: 350
# Step: 180, Model: 1, Loss: 4.9302215576171875, Num of Events: 170
# Step: 180, Model: 2, Loss: 0.9691575169563293, Num of Events: 115
# Step: 185, Model: 0, Loss: 18.169361114501953, Num of Events: 350
# Step: 185, Model: 1, Loss: 18.920368194580078, Num of Events: 170
# Step: 185, Model: 2, Loss: 0.9300521016120911, Num of Events: 115
# Step: 190, Model: 0, Loss: 34.083839416503906, Num of Events: 350
# Step: 190, Model: 1, Loss: 16.709945678710938, Num of Events: 170
# Step: 190, Model: 2, Loss: 1.066880464553833, Num of Events: 115
# Step: 195, Model: 0, Loss: 43.49037551879883, Num of Events: 350
# Step: 195, Model: 1, Loss: 32.74827575683594, Num of Events: 170
# Step: 195, Model: 2, Loss: 0.9329354763031006, Num of Events: 115

# %%
colors = ['red', 'green', 'blue']
for i in range(3):
    plt.plot(l[i], color = colors[i])

t = [len(l[i]) for i in range(3)]

print(f'Len of losses: {t}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 colors = ['red', 'green', 'blue']
#       2 for i in range(3):
# ----> 3     plt.plot(l[i], color = colors[i])
#       5 t = [len(l[i]) for i in range(3)]
#       7 print(f'Len of losses: {t}')
#
# NameError: name 'l' is not defined

# %%
s = []
for element in mpp.causes[0]:
    for j in element:
        s.append(j.argmax())
# s

# %%
matrix = mpp.GrangerMatrix.softmax(dim = 1).detach().cpu().numpy()

plt.imshow(matrix)
plt.axis('off')
plt.colorbar()

# %%
mpp.GrangerMatrix.detach().cpu().numpy()
# Out:
# array([[-2.1188912 , -1.4474473 ,  2.9192102 ],
#        [-2.4364383 , -0.91508734,  2.433953  ],
#        [-2.079296  , -1.5371398 ,  2.9367807 ]], dtype=float32)

# %%
final = []
for proc in range(3):
    proc_size = len(processes[proc])
    loss_size = len(l[proc])
    temp = [ sum(l[proc][i:i + proc_size])/proc_size for i in range(0, loss_size - proc_size, proc_size)]
    final.append(temp)

colors = ['red', 'green', 'blue']
for i in range(3):
    plt.plot(final[i], color = colors[i])

# %%
temp
# Out:
# [905.976876769747, 824.3470450299127, 720.2255801473345]

# %%
s = [i.argmax().item() for i in mpp.causes[0]]
s = torch.tensor(s)
s.unique(return_counts = True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 s = [i.argmax().item() for i in mpp.causes[0]]
#       2 s = torch.tensor(s)
#       3 s.unique(return_counts = True)
#
# Cell In[74], line 1, in <listcomp>(.0)
# ----> 1 s = [i.argmax().item() for i in mpp.causes[0]]
#       2 s = torch.tensor(s)
#       3 s.unique(return_counts = True)
#
# AttributeError: 'list' object has no attribute 'argmax'

# %%
causes = []
for i in mpp.causes[0]:
    for j in i:
        causes.append(j.argmax().item())
causes = torch.tensor(causes)
causes.unique(return_counts = True)
# Out:
# (tensor([0, 1, 2]), tensor([112, 125, 112]))
